# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("insurance_data.csv")
df
# 0 = not
# 1 = Yes
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age, df.bought_insurance)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test , y_train, y_test  = train_test_split(df[['age']] , df.bought_insurance , train_size = 0.8)

# %%
from sklearn.linear_model import LogisticRegression

# %%
mod = LogisticRegression()
mod.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
mod.predict(X_test)
# Out:
# array([1, 1, 1, 0, 0, 0])

# %%
X_test
# Out:
#     age
# 14   49
# 5    56
# 2    47
# 26   23
# 10   18
# 18   19

# %%
mod.score(X_test, y_test)*100
# Small Dataset
# Out:
# 100.0

# %%
mod.predict([[78]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
mod.predict_proba(X_test)
# predict the probability of two classes of X_test values
# Out:
# array([[0.2548175 , 0.7451825 ],
#        [0.13237938, 0.86762062],
#        [0.30100645, 0.69899355],
#        [0.87262285, 0.12737715],
#        [0.92419651, 0.07580349],
#        [0.91571448, 0.08428552]])
