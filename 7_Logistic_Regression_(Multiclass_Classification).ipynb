# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X = df[['SepalLengthCm','SepalWidthCm' , 'PetalLengthCm' ,'PetalWidthCm']]
y = df['Species']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
X_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1              4.9           3.0            1.4           0.2
# 18             5.7           3.8            1.7           0.3
# 133            6.3           2.8            5.1           1.5
# 128            6.4           2.8            5.6           2.1
# 40             5.0           3.5            1.3           0.3
# 85             6.0           3.4            4.5           1.6
# 10             5.4           3.7            1.5           0.2
# 80             5.5           2.4            3.8           1.1
# 88             5.6           3.0            4.1           1.3
# 35             5.0           3.2            1.2           0.2
# 149            5.9           3.0            5.1           1.8
# 57             4.9           2.4            3.3           1.0
# 17             5.1           3.5            1.4           0.3
# 22             4.6           3.6            1.0           0.2
# ...

# %%
from sklearn.linear_model import LogisticRegression
model =  LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[5.1,	3.5,	1.4,	0.2]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Iris-setosa'], dtype=object)

# %%
model.score(X_test,y_test)*100
# Out:
# 93.33333333333333

# %% [markdown]
# A **confusion matrix** is a table that is used to evaluate the performance of a classification algorithm on a set of test data for which the true values (actual class labels) are known. It is a useful tool for assessing the performance of a classification model by summarizing the number of **true positives (TP)**, **true negatives (TN)**, **false positives (FP)**, and **false negatives (FN)** predictions.
#
# In a confusion matrix, the four main terms are:
#
# 1. **True Positives (TP):** The number of instances that were correctly predicted as positive. In other words, the number of cases where the model predicted the positive class, and the true class was also positive.
#
# 2. **True Negatives (TN):** The number of instances that were correctly predicted as negative. In other words, the number of cases where the model predicted the negative class, and the true class was also negative.
#
# 3. **False Positives (FP):** The number of instances that were incorrectly predicted as positive. In other words, the number of cases where the model predicted the positive class, but the true class was actually negative.
#
# 4. **False Negatives (FN):** The number of instances that were incorrectly predicted as negative. In other words, the number of cases where the model predicted the negative class, but the true class was actually positive.

# %%
from sklearn.metrics import confusion_matrix
y_predicted = model.predict(X_test)

cf = confusion_matrix(y_test , y_predicted)
cf
# Out:
# array([[12,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  2,  7]])

# %%
import seaborn as sns
sns.heatmap(cf, annot=True)
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(50.722222222222214, 0.5, 'Actual')
